# %%
# Importação das bibliotecas 
# %pylab inline 
 
path = 'DRIVE/training/'
# Leitura da imagem com a função imread() 
imagem = imread(path + "images/21_training.tif")

print('Largura em pixels: ', end='') 
print(imagem.shape[1]) #largura da imagem 

print('Altura em pixels: ', end='') 
print(imagem.shape[0]) #altura da imagem 

print('Qtde de canais: ', end='') 
print(imagem.shape[2]) # Mostra a imagem com a função imshow 

pylab.imshow(imagem)
pylab.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Largura em pixels: 565
# Altura em pixels: 584
# Qtde de canais: 3

# %%
# Importação das bibliotecas 
# %pylab inline
import matplotlib 
import numpy as np
import cv2

path = 'DRIVE/training/'
# Leitura da imagem com a função imread() 
img = cv2.imread(path + "images/22_training.tif")

histR = cv2.calcHist([img], [0],None,[256],[0,256])
plt.figure()
plt.title("Histograma Red")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.hist(histR.ravel(), 256, [0,256])
plt.xlim([0, 256])
plt.show()

histG = cv2.calcHist([img], [1],None,[256],[0,256])
plt.figure()
plt.title("Histograma Green")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.hist(histR.ravel(), 256, [0,256])
plt.xlim([0, 256])
plt.show()

histB = cv2.calcHist([img], [2],None,[256],[0,256])
plt.figure()
plt.title("Histograma Blue")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.hist(histR.ravel(), 256, [0,256])
plt.xlim([0, 256])
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.figure()
plt.title("Histograma Original")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.hist(img.ravel(), 256, [0,256])
plt.xlim([0, 256])
plt.show()

# %%
# Importação das bibliotecas 
# %pylab inline
import matplotlib 
import numpy as np
import cv2

path = 'DRIVE/training/'
# Leitura da imagem com a função imread() 
img = cv2.imread(path + "images/22_training.tif")

pylab.imshow(img)
pylab.show()

hist,bins = np.histogram(img.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

cdf_m = np.ma.masked_equal(cdf,0)
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())
cdf = np.ma.filled(cdf_m,0).astype('uint8')

img2 = cdf[img]

pylab.imshow(img2)
pylab.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\migue\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:161: UserWarning: pylab import has clobbered these variables: ['hist']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
ef myEqualize(im)
    im=im.convert('L')
    contr = ImageEnhance.Contrast(im)
    im = contr.enhance(0.3)
    bright = ImageEnhance.Brightness(im)
    im = bright.enhance(2)
    #im.show()
    return im

# %%
'''    
    # Leitura da imagem com a função imread() 
    img = cv2.imread(path + "images/21_training.tif")
    pylab.imshow(img)
    pylab.show()
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    h_eq = cv2.equalizeHist(img)
    plt.figure()
    plt.title("Histograma Equalizado")
    plt.xlabel("Intensidade")
    plt.ylabel("Qtde de Pixels")
    plt.hist(h_eq.ravel(), 256, [0,256])
    plt.xlim([0, 256])
    plt.show()
    plt.figure()
    plt.title("Histograma Original")
    plt.xlabel("Intensidade")
    plt.ylabel("Qtde de Pixels")
    plt.hist(img.ravel(), 256, [0,256])
    plt.xlim([0, 256])
    plt.show()

    pylab.imshow(img)
    pylab.show()'''
